# %%
import pandas as pd
import numpy as np
from preprocess import preprocess_MIMIC
import matplotlib.pyplot as plt
from statistics import mean
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from preprocess import preprocess_CXP
#       4 import matplotlib.pyplot as plt
#       5 from statistics import mean
#
# ImportError: cannot import name 'preprocess_CXP' from 'preprocess' (C:\Users\Andrei\PycharmProjects\Underdiagnosis_NatMed\MIMIC\preprocess.py)

# %%
metadata_labeled = pd.read_csv('data/mimic-cxr-jpg/2.0.0/mimic-cxr-2.0.0-chexpert.csv')
display(metadata_labeled.head(10))
# Out:
#    subject_id  study_id  Atelectasis  Cardiomegaly  Consolidation  Edema  \
# 0    10000032  50414267          NaN           NaN            NaN    NaN
# 1    10000032  53189527          NaN           NaN            NaN    NaN
# 2    10000032  53911762          NaN           NaN            NaN    NaN
# 3    10000032  56699142          NaN           NaN            NaN    NaN
# 4    10000764  57375967          NaN           NaN            1.0    NaN
# 5    10000898  50771383          NaN           NaN            NaN    NaN
# 6    10000898  54205396          NaN           NaN            NaN    NaN
# 7    10000935  50578979          NaN           NaN            NaN   -1.0
# 8    10000935  51178377          NaN           NaN            NaN    NaN
# 9    10000935  55697293          NaN           NaN            NaN    NaN
#
#    Enlarged Cardiomediastinum  Fracture  Lung Lesion  Lung Opacity  \
# 0                         NaN       NaN          NaN           NaN
# ...

# %%
admissions = pd.read_csv('data/mimiciv/0.4/core/admissions.csv')
patients = pd.read_csv('data/mimiciv/0.4/core/patients.csv')
display(admissions.head(10))
display(admissions.columns)
display(patients.head(10))
# Out:
#    subject_id   hadm_id            admittime            dischtime deathtime  \
# 0    12427812  21593330  2184-01-06 11:51:00  2184-01-10 11:45:00       NaN
# 1    14029832  22059088  2120-01-18 01:28:00  2120-01-20 16:13:00       NaN
# 2    14495017  22484010  2175-01-28 15:41:00  2175-01-29 16:00:00       NaN
# 3    13676048  23865469  2193-01-19 05:27:00  2193-01-24 18:59:00       NaN
# 4    13831972  27763544  2131-01-27 04:03:00  2131-01-27 05:39:00       NaN
# 5    18523038  25414328  2142-08-26 17:14:00  2142-08-27 10:00:00       NaN
# 6    16705931  20580522  2174-10-24 11:30:00  2174-10-24 18:45:00       NaN
# 7    19963742  24951506  2171-07-04 15:58:00  2171-07-05 13:37:00       NaN
# 8    10903424  22568585  2181-01-31 13:09:00  2181-01-31 13:42:00       NaN
# 9    15030422  21975876  2149-09-21 23:54:00  2149-09-22 03:59:00       NaN
#
#            admission_type      admission_location discharge_location  \
# ...

# %%
# admissions.drop(columns=['hadm_id','admittime', 'dischtime', 'deathtime',
#        'admission_type', 'admission_location', 'discharge_location', 'edregtime', 'edouttime', 'hospital_expire_flag'], inplace=True, errors='ignore')
admissions.head()
# Out:
#    subject_id insurance language marital_status ethnicity
# 0    12427812     Other  ENGLISH            NaN   UNKNOWN
# 1    14029832     Other  ENGLISH            NaN     OTHER
# 2    14495017     Other        ?            NaN     WHITE
# 3    13676048     Other        ?        MARRIED     WHITE
# 4    13831972  Medicaid  ENGLISH         SINGLE     WHITE

# %%
#patients.drop(columns=['anchor_year', 'dod', 'anchor_year_group'], inplace=True, errors='ignore')
patients.head()
# Out:
#    subject_id gender  anchor_age
# 0    10002723      F           0
# 1    10003939      M           0
# 2    10004222      M           0
# 3    10005325      F           0
# 4    10007338      F           0

# %%
demographics = pd.merge(admissions, patients, how='left', on='subject_id')
#demographics.head()
demographics.to_csv('data/demographics.csv', index=False)
